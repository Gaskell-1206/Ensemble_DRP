# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Dataset/Coronna_Data_CERTAIN_0M_3M.csv')

# %%
df
# Out:
#     UNMC_id     grp    init_group  futime   age  gender final_education  \
# 0    U00003  enbrel  bionaive TNF     0.0  54.0    male   college/univ.
# 1    U00016  cimzia  bionaive TNF     0.0  62.0    male   college/univ.
# 2    U00017  enbrel  bionaive TNF     0.0  54.0  female   college/univ.
# 3    U00018  enbrel  bionaive TNF     0.0  63.0  female   college/univ.
# 4    U00022  enbrel  bionaive TNF     0.0  61.0  female   college/univ.
# ..      ...     ...           ...     ...   ...     ...             ...
# 405  U01222  humira  bionaive TNF     0.0  49.0  female   college/univ.
# 406  U01223  enbrel  bionaive TNF     0.0  24.0  female   college/univ.
# 407  U01227  humira  bionaive TNF     0.0  61.0  female   college/univ.
# 408  U01228  enbrel  bionaive TNF     0.0  57.0    male         primary
# 409  U01229  cimzia  bionaive TNF     0.0  23.0  female   college/univ.
#
#     race_grp  ethnicity  weight  ...  md_global_assess  pt_global_assess  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 62 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNMC_id            410 non-null    object
#  1   grp                410 non-null    object
#  2   init_group         410 non-null    object
#  3   futime             410 non-null    float64
#  4   age                409 non-null    float64
#  5   gender             409 non-null    object
#  6   final_education    407 non-null    object
#  7   race_grp           410 non-null    object
#  8   ethnicity          400 non-null    float64
#  9   weight             409 non-null    float64
#  10  BMI                409 non-null    float64
#  11  height             410 non-null    float64
#  12  newsmoker          398 non-null    object
#  13  smkyrs             102 non-null    float64
#  14  numcigs            92 non-null     float64
#  15  drinker            405 non-null    object
# ...

# %% [markdown]
# ## drugs group

# %%
sns.countplot('grp',data=df)
# Out:
# /Users/gaskell/miniforge_x86_64/envs/ADPred_new/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='grp', ylabel='count'>

# %% [markdown]
# ## Gender

# %%
sns.countplot('gender',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ## Age

# %%
sns.distplot(df['age'], bins=50, kde=True, rug=True)
# Out:
# /Users/gaskell/miniforge_x86_64/envs/ADPred_new/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/gaskell/miniforge_x86_64/envs/ADPred_new/lib/python3.10/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>
