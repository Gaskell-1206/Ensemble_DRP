# %%
import sys
sys.path.insert(0, r'C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR\DataModule')
sys.path.insert(0, r'C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR')
sys.path.insert(0, r'C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR\EnsambleModule')
import Data_Preparation
import EvaluationModule 
import ensamble_model

# %%
## building test model
temp=ensamble_model.make_ensamble(model_list={'Logistic':{'penalty':'none'}},ensamble_type="Stacking", challange='Classification').model
temp
# Out:
# StackingClassifier(estimators=[('Logistic',
#                                 LogisticRegression(penalty='none'))])

# %%
path=r'C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR\Dataset'
dataset = Data_Preparation.CoronnaCERTAINDataset(
    library_root=path,
    challenge="binary_classification", #option: regression, regression_delta, classification, binary_classification
    dataset='CORRONA CERTAIN', 
    process_approach='SC', #option: KVB, SC
    imputation="IterativeImputer", #option: SimpleFill, KNN, SoftImpute, BiScaler, NuclearNormMinimization, IterativeImputer, IterativeSVD, None(raw)
    patient_group='bionaive TNF', #option: "all", "bioexp nTNF", "bionaive TNF", "bionaive orencia", "KVB"
    drug_group='all', #option: "all", "actemra", "cimzia", "enbrel", "humira", "orencia", "remicade", "rituxan", "simponi"
    time_points=(0,3), 
    train_test_rate=0.8,
    remove_low_DAS = True,
    save_csv=True,
    random_state=2022)
train, train_loc = dataset.get_train()
test, test_loc = dataset.get_test()


## train test split 
X_train = train.iloc[:,:-1]
y_train = train.iloc[:,-1]
X_test = test.iloc[:,:-1]

y_test = test.iloc[:,-1]
# Out:
# feature engineering, drop columns due to 70% missing value: Index(['smkyrs', 'numcigs', 'rfstatus_impute', 'ccpstatus_impute',
#        'statin_use'],
#       dtype='object')
# Missing values in train before imputation: 128
# Missing values in train after imputation: 0
# Missing values in test before imputation: 24
# Missing values in test after imputation: 0
# Label Encoder, 0: Non-responders (No Response), 1: Responders(Good, Moderate)
# save file to: C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR\Dataset\Coronna_Data_CERTAIN_binary_classification_SC_0M_3M_bionaive TNF_all\Train.csv
# Label Encoder, 0: Non-responders (No Response), 1: Responders(Good, Moderate)
# save file to: C:\Users\buzga\Desktop\School\Reaserch\Langone\ML_RA_EHR\Dataset\Coronna_Data_CERTAIN_binary_classification_SC_0M_3M_bionaive TNF_all\Test.csv

# %%
# Out:
#                                                                                                                                                            MAE  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
#
#                                                                                                                                                            MSE  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          NaN
#
#                                                                                                                                                            RMSE  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022           NaN
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022           NaN
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022           NaN
#
#                                                                                                                                                            R2  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022         NaN
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022         NaN
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022         NaN
#
#                                                                                                                                                            Pearson_Correlation  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022                          NaN
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022                          NaN
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022                          NaN
#
#                                                                                                                                                            Accuracy  \
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.772131
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.729508
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.718033
#
#                                                                                                                                                            F1-Score
# model_id          dataset    challenge             process_approach imputation       patient_group drug_group train_test_rate remove_low_DAS random_state
# Logistic Stacking validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.435078
# linear bag        validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.477346
# linear boost      validation binary_classification SC               IterativeImputer bionaive TNF  all        0.8             True           2022          0.510871
